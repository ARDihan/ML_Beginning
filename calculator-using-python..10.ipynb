# %%
num1 = float(input("Enter first number: "))
oper = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))
while True:
    if oper == "+":
        print("Result:", num1 + num2)
    elif oper=='-':
        print('Result is :',num1-num2)
    elif oper=='*':
        print('Result is :', num1*num2)
    elif oper=='/':
        print('Result is :',num1/num2)
    else:
        print('Invalid operator')
    again = input("Do you want to calculate again? (yes/no): ").lower()
    if again != "yes":
        print("Goodbye!")
        break
# Out:
# Enter first number:  78
# Enter operator (+, -, *, /):  /
# Enter second number:  90
# Result is : 0.8666666666666667
# Do you want to calculate again? (yes/no):  yes
# Result is : 0.8666666666666667
# Do you want to calculate again? (yes/no):  no
# Goodbye!

# %%
celcius=float(input('Enter the celcius value of temparature:'))

print('Temp in farenhite:',(9*celcius)/5+32)
# Out:
# Enter the celcius value of temparature: 45
# Temp in farenhite: 113.0

# %%
number=int(input('Enter the number:'))
total=0
i=1
while i<number:
    total=i+1
print("Sum from 1 to",number,"is",total)
